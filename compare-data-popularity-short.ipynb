# %% [markdown]
# ## Order a set of datasets with the dataset popularity listing
#
# This is an attempt to use the dataset popularity listing to select the most relevant samples among a list of MC samples proposed as legacy.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read in the dataset listings
#
# #### Dataset listing from CMSDAS
#
# The dataset listing is from CMSDAS (https://cmsweb.cern.ch/das/request?view=plain&limit=50&instance=prod%2Fglobal&input=dataset%3D%2F*%2F*START42*%2FAODSIM)
#
# Read it in to a dataframe.

# %%
datasets = pd.read_csv('datasets.txt', sep=" ", header=None)

# %%
datasets.head()
# Out:
#                                                    0
# 0  /2B1Jet_TuneZ2_7TeV-alpgen-pythia6/Fall11-PU_S...
# 1  /2B2C1Jet_TuneZ2_7TeV-alpgen-pythia6/Fall11-PU...
# 2  /2B2C_TuneZ2_7TeV-alpgen-pythia6/Fall11-PU_S6_...
# 3  /2B2Jets_TuneZ2_7TeV-alpgen-pythia6/Fall11-PU_...
# 4  /2B3Jets_TuneZ2_7TeV-alpgen-pythia6/Fall11-PU_...

# %% [markdown]
# #### Dataset popularity list
#
# The dataset popularity json file is from https://cmsweb.cern.ch/popdb/popularity/dataSetTable
#
# Read it in to a dataframe.

# %%
datapop = pd.read_json('datasets_start2010-01-01_stop2012-03-31.json')

# %%
datapop.head()
# Out:
#                                                 DATA SITENAME
# 0  {'NACC': 2900135, 'TOTCPU': 3296253, 'NUSERS':...  summary
# 1  {'NACC': 2026464, 'TOTCPU': 2056789, 'NUSERS':...  summary
# 2  {'NACC': 1026045, 'TOTCPU': 2053499, 'NUSERS':...  summary
# 3  {'NACC': 1262370, 'TOTCPU': 1915483, 'NUSERS':...  summary
# 4  {'NACC': 1537482, 'TOTCPU': 1765946, 'NUSERS':...  summary

# %% [markdown]
# It comes in two parts, DATA and SITENAME, but only the DATA part is relevant in this context:

# %%
new_df = pd.DataFrame(list(datapop['DATA']))

# %%
new_df.head()
# Out:
#                                             COLLNAME     NACC  NUSERS RNACC  \
# 0  /WJetsToLNu_TuneZ2_7TeV-madgraph-tauola/Summer...  2900135    3667   2.7
# 1  /DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola/S...  2026464    3786   1.9
# 2  /TTJets_TuneZ2_7TeV-madgraph-tauola/Fall11-PU_...  1026045     948   0.9
# 3               /SingleMu/Run2011B-PromptReco-v1/AOD  1262370    2238   1.2
# 4               /SingleMu/Run2011A-PromptReco-v4/AOD  1537482    3571   1.4
#
#   RNUSERS RTOTCPU   TOTCPU
# 0     1.3     5.2  3296253
# 1     1.3     3.3  2056789
# 2     0.3     3.2  2053499
# 3     0.8     3.0  1915483
# 4     1.3     2.8  1765946

# %% [markdown]
# Sort the dataframe for the number of users:

# %%
new_df = new_df.sort_values('NUSERS',ascending=False)

# %% [markdown]
# ### Find out the popularity order for a selected list of datasets
#
# Find in this ordered popularity list the dataset names which appear in `datasets`

# %% [markdown]
# Now instead of looking for the rows one by one, we can find all corresponding rows in the dataframe.
# Write the list of datasets from the `datasets` to a list, see https://stackoverflow.com/questions/19585280/convert-a-row-in-pandas-into-list

# %%
datalist = datasets[0].values.tolist()

# %% [markdown]
# Select rows based on a list, see https://stackoverflow.com/questions/12096252/use-a-list-of-values-to-select-rows-from-a-pandas-dataframe?rq=1

# %%
new_df[new_df['COLLNAME'].isin(datalist)]
# Out:
#                                                 COLLNAME     NACC  NUSERS  \
# 6      /DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola/F...   923959    1266
# 5      /WJetsToLNu_TuneZ2_7TeV-madgraph-tauola/Fall11...   987978    1180
# 2      /TTJets_TuneZ2_7TeV-madgraph-tauola/Fall11-PU_...  1026045     948
# 163    /TTJets_TuneZ2_7TeV-madgraph-tauola/Fall11-PU_...    74208     397
# 50     /DYToMuMu_M-20_CT10_TuneZ2_7TeV-powheg-pythia/...   214307     393
# 61     /DYToEE_M-20_CT10_TuneZ2_7TeV-powheg-pythia/Fa...   173031     266
# 213    /WZ_TuneZ2_7TeV_pythia6_tauola/Fall11-PU_S6_ST...    48271     260
# 43     /QCD_Pt-30to80_EMEnriched_TuneZ2_7TeV-pythia/F...   368661     252
# 210    /ZZ_TuneZ2_7TeV_pythia6_tauola/Fall11-PU_S6_ST...    48289     250
# 204    /WW_TuneZ2_7TeV_pythia6_tauola/Fall11-PU_S6_ST...    37441     233
# 95     /DYToTauTau_M-20_CT10_TuneZ2_7TeV-powheg-pythi...   100141     216
# 546    /T_TuneZ2_tW-channel-DR_7TeV-powheg-tauola/Fal...    10168     206
# 225    /T_TuneZ2_t-channel_7TeV-powheg-tauola/Fall11-...    32358     206
# 93     /QCD_Pt-20_MuEnrichedPt-15_TuneZ2_7TeV-pythia6...    87414     204
# 83     /QCD_Pt-20to30_EMEnriched_TuneZ2_7TeV-pythia6/...   139363     179
# 372    /Tbar_TuneZ2_t-channel_7TeV-powheg-tauola/Fall...    17167     165
# 889    /T_TuneZ2_s-channel_7TeV-powheg-tauola/Fall11-...     3744     140
# 98     /DYJetsToLL_M-10To50_TuneZ2_7TeV-madgraph/Fall...   119603     134
# 1131   /Tbar_TuneZ2_s-channel_7TeV-powheg-tauola/Fall...     2067     123
# 123    /QCD_Pt-40_doubleEMEnriched_TuneZ2_7TeV-pythia...   101368     119
# 155    /QCD_Pt-50to80_MuPt5Enriched_TuneZ2_7TeV-pythi...    30240     117
# 293    /QCD_Pt-170to300_TuneZ2_7TeV_pythia6/Fall11-PU...    25626     117
# 161    /TTTo2L2Nu2B_7TeV-powheg-pythia6/Fall11-PU_S6_...    34609     115
# 307    /GJet_Pt-20_doubleEMEnriched_TuneZ2_7TeV-pythi...    21311     114
# 179    /QCD_Pt-20to30_MuPt5Enriched_TuneZ2_7TeV-pythi...    31809     112
# 130    /W1Jet_TuneZ2_7TeV-madgraph-tauola/Fall11-PU_S...    70824     110
# 605    /QCD_Pt-30to80_BCtoE_TuneZ2_7TeV-pythia6/Fall1...    18920     101
# 688    /Tbar_TuneZ2_tW-channel-DR_7TeV-powheg-tauola/...     5507     100
# 180    /QCD_Pt-30to50_MuPt5Enriched_TuneZ2_7TeV-pythi...    31109      99
# 366    /QCD_Pt-150_MuPt5Enriched_TuneZ2_7TeV-pythia6/...    13116      98
# ...                                                  ...      ...     ...
# 9145   /VBF_ToHToZZTo4L_M-120_7TeV-powheg-pythia6/Fal...        7       1
# 4866   /GluGluToHToZZTo4L_M-190_7TeV-powheg-pythia6/F...       29       1
# 9101   /GluGluToHToZZTo2L2Q_M-600_7TeV-powheg-pythia6...        6       1
# 9119   /VBF_ToHToZZTo2L2NU_M-550_7TeV-powheg-pythia6/...        9       1
# 4846   /4B1Jet_TuneZ2_7TeV-alpgen-pythia6/Fall11-PU_S...       55       1
# 9297   /VBF_HToWWToLNuTauNu_M-230_7TeV-powheg-pythia6...        7       1
# 9251   /GluGluToHToZZTo2L2Q_M-210_7TeV-powheg-pythia6...        7       1
# 17974  /WprimeToTBTolnubb_M-2300_RightWprime_TuneZ2_7...       35       1
# 2829   /IM_tb40_L1_300_400_sftsht_7TeV-pythia6/Fall11...       59       1
# 17216  /QstarToQW_M_1000_TuneZ2_7TeV_pythia6/Fall11-P...       13       1
# 17057  /WprimeToTBTolnubb_M-1700_MixedWprimePlusSM_Tu...       36       1
# 17458  /WprimeToTBTolnubb_M-2100_RightWprime_TuneZ2_7...       35       1
# 2644   /IM_tb40_L2_650_550_sftsht_7TeV-pythia6/Fall11...       60       1
# 2634   /IM_tb10_L2_225_550_sftsht_7TeV-pythia6/Fall11...       60       1
# 19032  /MajoranaNeutrinoToMuMu_M-75_7TeV_Alpgen/Fall1...        4       1
# 2758   /IM_tb40_L1_350_500_sftsht_7TeV-pythia6/Fall11...       57       1
# 18834  /QCD_Pt-15to3000_TuneZ2_Flat_7TeV_pythia6/Fall...      742       1
# 15109  /ZGToNuNuG_Pt-130_M-45_TuneZ2_7TeV-pythia6/Fal...       12       1
# 15043  /WprimeToTBTolnubb_M-2200_MixedWprimePlusSM_Tu...       35       1
# 15369  /WWminusTo2L2Nu_7TeV-madgraph/Fall11-PU_S6_STA...        1       1
# 15432  /WprimeToTBTolnubb_M-2200_LeftWprimePlusSM_Tun...       35       1
# 15476  /QstarCIToQZ_ee_M_2000_7TeV_pythia6/Fall11-PU_...        1       1
# 15266  /TTLminusNu_TuneZ2_7TeV-madgraph-tauola/Fall11...        3       1
# 14290  /GluGluToHToZZTo2L2Q_M-220_7TeV-powheg-pythia6...        9       1
# 14673  /MajoranaNeutrinoToMuMu_M-50_7TeV_Alpgen/Fall1...        4       1
# 14605  /WprimeToTBTolnubb_M-1700_RightWprime_TuneZ2_7...       35       1
# 16856  /TTTT_TuneZ2_XDIM_7TeV-madgraph-tauola/Fall11-...      200       1
# 15801  /WprimeToTBTolnubb_M-2100_LeftWprimePlusSM_Tun...       35       1
# 3241   /4C_TuneZ2_7TeV-alpgen-pythia6/Fall11-PU_S6_ST...      145       1
# 15648  /MajoranaNeutrinoToMuMu_M-85_7TeV_Alpgen/Fall1...        5       1
#
#       RNACC RNUSERS RTOTCPU   TOTCPU
# 6       0.9     0.4     1.7  1059471
# 5       0.9     0.4     1.8  1167262
# 2       0.9     0.3     3.2  2053499
# 163     0.1     0.1     0.1    69849
# 50      0.2     0.1     0.4   249990
# 61      0.2     0.1     0.3   194591
# 213     0.0     0.1     0.1    51386
# 43      0.3     0.1     0.5   288726
# 210     0.0     0.1     0.1    52181
# 204     0.0     0.1     0.1    54748
# 95      0.1     0.1     0.2   117405
# 546     0.0     0.1     0.0    11375
# 225     0.0     0.1     0.1    47767
# 93      0.1     0.1     0.2   119359
# 83      0.1     0.1     0.2   129813
# 372     0.0     0.1     0.0    25194
# 889     0.0     0.0     0.0     3710
# 98      0.1     0.0     0.2   112918
# 1131    0.0     0.0     0.0     2161
# 123     0.1     0.0     0.1    93712
# 155     0.0     0.0     0.1    74579
# 293     0.0     0.0     0.1    34942
# 161     0.0     0.0     0.1    70476
# 307     0.0     0.0     0.1    32627
# 179     0.0     0.0     0.1    62115
# 130     0.1     0.0     0.1    90377
# 605     0.0     0.0     0.0     9234
# 688     0.0     0.0     0.0     6944
# 180     0.0     0.0     0.1    61314
# 366     0.0     0.0     0.0    25659
# ...     ...     ...     ...      ...
# 9145    0.0     0.0     0.0        8
# 4866    0.0     0.0     0.0       76
# 9101    0.0     0.0     0.0        9
# 9119    0.0     0.0     0.0        8
# 4846    0.0     0.0     0.0       77
# 9297    0.0     0.0     0.0        8
# 9251    0.0     0.0     0.0        8
# 17974   0.0     0.0       0        0
# 2829    0.0     0.0     0.0      275
# 17216   0.0     0.0       0        0
# 17057   0.0     0.0       0        0
# 17458   0.0     0.0       0        0
# 2644    0.0     0.0     0.0      325
# 2634    0.0     0.0     0.0      327
# 19032   0.0     0.0       0        0
# 2758    0.0     0.0     0.0      294
# 18834   0.0     0.0       0        0
# 15109   0.0     0.0       0        0
# 15043   0.0     0.0       0        0
# 15369   0.0     0.0       0        0
# 15432   0.0     0.0       0        0
# 15476   0.0     0.0       0        0
# 15266   0.0     0.0       0        0
# 14290   0.0     0.0       0        0
# 14673   0.0     0.0       0        0
# 14605   0.0     0.0       0        0
# 16856   0.0     0.0       0        0
# 15801   0.0     0.0       0        0
# 3241    0.0     0.0     0.0      205
# 15648   0.0     0.0       0        0
#
# [948 rows x 7 columns]

# %% [markdown]
# Write the ordered list in a text file

# %%
np.savetxt(r'np.txt', new_df[new_df['COLLNAME'].isin(datalist)]['COLLNAME'].values, fmt='%s')

# %% [markdown]
# ### Popularity listing by process name
#
# Try to see whether searching for just the first part of the dataset name makes a difference. To do this, one needs first to combine the different reprocessings in the popularity listing in one entry and sum the value for NACC, NUSERS and TOTCPU. Use only the first part of the dataset name (between the two first "/"). Then for search, use the corresponding part of the dataset name in the listing.
#
# Split the string first, see https://stackoverflow.com/questions/32425334/splitting-a-string-in-a-python-dataframe

# %% [markdown]
# Insert the split parts of the full dataset name (process, reprocessing and datatype) to the dataframe:

# %%
new_df['process'] = new_df.COLLNAME.str.split('/').str[1]
new_df['reprocessing'] = new_df.COLLNAME.str.split('/').str[2]
new_df['datatype'] = new_df.COLLNAME.str.split('/').str[3]

# %%
new_df.head()
# Out:
#                                             COLLNAME     NACC  NUSERS RNACC  \
# 1  /DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola/S...  2026464    3786   1.9
# 0  /WJetsToLNu_TuneZ2_7TeV-madgraph-tauola/Summer...  2900135    3667   2.7
# 4               /SingleMu/Run2011A-PromptReco-v4/AOD  1537482    3571   1.4
# 7              /SingleMu/Run2011A-May10ReReco-v1/AOD  2851106    3082   2.6
# 3               /SingleMu/Run2011B-PromptReco-v1/AOD  1262370    2238   1.2
#
#   RNUSERS RTOTCPU   TOTCPU                                      process  \
# 1     1.3     3.3  2056789  DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola
# 0     1.3     5.2  3296253       WJetsToLNu_TuneZ2_7TeV-madgraph-tauola
# 4     1.3     2.8  1765946                                     SingleMu
# 7     1.1     1.5   966514                                     SingleMu
# 3     0.8     3.0  1915483                                     SingleMu
#
#                     reprocessing datatype
# 1  Summer11-PU_S4_START42_V11-v1   AODSIM
# 0  Summer11-PU_S4_START42_V11-v1   AODSIM
# 4         Run2011A-PromptReco-v4      AOD
# 7        Run2011A-May10ReReco-v1      AOD
# 3         Run2011B-PromptReco-v1      AOD

# %% [markdown]
# Separate the listing for MC and data - as a first approximation data does not have - or _ in the process name.

# %%
#new_df = new_df[(new_df['datatype'] != 'AOD')] 
#new_df = new_df[(new_df['datatype'] != 'RECO')]
#new_df = new_df[(new_df['datatype'] != 'RAW')]
mc_df  = new_df[new_df["process"].str.contains('-|_')==True]
data_df = new_df[new_df["process"].str.contains('-|_')==False]

mc_df.head(20)
# Out:
#                                               COLLNAME     NACC  NUSERS RNACC  \
# 1    /DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola/S...  2026464    3786   1.9
# 0    /WJetsToLNu_TuneZ2_7TeV-madgraph-tauola/Summer...  2900135    3667   2.7
# 23   /TTJets_TuneZ2_7TeV-madgraph-tauola/Summer11-P...   329509    1898   0.3
# 6    /DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola/F...   923959    1266   0.9
# 5    /WJetsToLNu_TuneZ2_7TeV-madgraph-tauola/Fall11...   987978    1180   0.9
# 27   /WJetsToLNu_TuneZ2_7TeV-madgraph-tauola/Spring...   573031    1076   0.5
# 2    /TTJets_TuneZ2_7TeV-madgraph-tauola/Fall11-PU_...  1026045     948   0.9
# 10   /QCD_Pt-30to80_EMEnriched_TuneZ2_7TeV-pythia/S...   688387     803   0.6
# 101  /T_TuneZ2_t-channel_7TeV-powheg-tauola/Summer1...   104410     731   0.1
# 46   /DYToMuMu_M-20_CT10_TuneZ2_7TeV-powheg-pythia/...   440509     724   0.4
# 124  /WZ_TuneZ2_7TeV_pythia6_tauola/Summer11-PU_S4_...   108720     660   0.1
# 135  /WW_TuneZ2_7TeV_pythia6_tauola/Summer11-PU_S4_...   105585     658   0.1
# 302  /T_TuneZ2_tW-channel-DR_7TeV-powheg-tauola/Sum...    32179     651   0.0
# 90   /TTJets_TuneZ2_7TeV-madgraph-tauola/Summer11-P...   123459     647   0.1
# 21   /QCD_Pt-20to30_EMEnriched_TuneZ2_7TeV-pythia6/...   339397     628   0.3
# 132  /ZZ_TuneZ2_7TeV_pythia6_tauola/Summer11-PU_S4_...    97916     625   0.1
# 330  /Tbar_TuneZ2_tW-channel-DR_7TeV-powheg-tauola/...    32253     619   0.0
# 34   /QCD_Pt-20_MuEnrichedPt-15_TuneZ2_7TeV-pythia6...   280484     619   0.3
# 200  /TTJets_TuneZ2_7TeV-madgraph-tauola/Spring11-P...   103888     610   0.1
# 340  /DYToEE_M-20_TuneZ2_7TeV-pythia6/Summer11-PU_S...   175404     596   0.2
#
#     RNUSERS RTOTCPU   TOTCPU                                        process  \
# 1       1.3     3.3  2056789    DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola
# 0       1.3     5.2  3296253         WJetsToLNu_TuneZ2_7TeV-madgraph-tauola
# 23      0.7     0.7   434610             TTJets_TuneZ2_7TeV-madgraph-tauola
# 6       0.4     1.7  1059471    DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola
# 5       0.4     1.8  1167262         WJetsToLNu_TuneZ2_7TeV-madgraph-tauola
# 27      0.4     0.6   401126         WJetsToLNu_TuneZ2_7TeV-madgraph-tauola
# 2       0.3     3.2  2053499             TTJets_TuneZ2_7TeV-madgraph-tauola
# 10      0.3     1.4   861974    QCD_Pt-30to80_EMEnriched_TuneZ2_7TeV-pythia
# 101     0.3     0.2   111721          T_TuneZ2_t-channel_7TeV-powheg-tauola
# 46      0.3     0.4   279291   DYToMuMu_M-20_CT10_TuneZ2_7TeV-powheg-pythia
# 124     0.2     0.1    93169                  WZ_TuneZ2_7TeV_pythia6_tauola
# 135     0.2     0.1    88181                  WW_TuneZ2_7TeV_pythia6_tauola
# 302     0.2     0.1    33270      T_TuneZ2_tW-channel-DR_7TeV-powheg-tauola
# 90      0.2     0.2   122916             TTJets_TuneZ2_7TeV-madgraph-tauola
# 21      0.2     0.7   459837   QCD_Pt-20to30_EMEnriched_TuneZ2_7TeV-pythia6
# 132     0.2     0.1    88974                  ZZ_TuneZ2_7TeV_pythia6_tauola
# 330     0.2     0.0    29578   Tbar_TuneZ2_tW-channel-DR_7TeV-powheg-tauola
# 34      0.2     0.5   334697  QCD_Pt-20_MuEnrichedPt-15_TuneZ2_7TeV-pythia6
# 200     0.2     0.1    55613             TTJets_TuneZ2_7TeV-madgraph-tauola
# 340     0.2     0.0    27979                DYToEE_M-20_TuneZ2_7TeV-pythia6
#
#                         reprocessing datatype
# 1      Summer11-PU_S4_START42_V11-v1   AODSIM
# 0      Summer11-PU_S4_START42_V11-v1   AODSIM
# 23     Summer11-PU_S4_START42_V11-v1   AODSIM
# 6       Fall11-PU_S6_START42_V14B-v1   AODSIM
# 5       Fall11-PU_S6_START42_V14B-v1   AODSIM
# 27   Spring11-PU_S1_START311_V1G1-v1   AODSIM
# 2       Fall11-PU_S6_START42_V14B-v2   AODSIM
# 10     Summer11-PU_S4_START42_V11-v1   AODSIM
# 101    Summer11-PU_S4_START42_V11-v1   AODSIM
# 46     Summer11-PU_S4_START42_V11-v1   AODSIM
# 124    Summer11-PU_S4_START42_V11-v1   AODSIM
# 135    Summer11-PU_S4_START42_V11-v1   AODSIM
# 302    Summer11-PU_S4_START42_V11-v1   AODSIM
# 90     Summer11-PU_S4_START42_V11-v2   AODSIM
# 21     Summer11-PU_S4_START42_V11-v1   AODSIM
# 132    Summer11-PU_S4_START42_V11-v1   AODSIM
# 330    Summer11-PU_S4_START42_V11-v1   AODSIM
# 34     Summer11-PU_S4_START42_V11-v1   AODSIM
# 200  Spring11-PU_S1_START311_V1G1-v1   AODSIM
# 340    Summer11-PU_S3_START42_V11-v2   AODSIM

# %%
data_df.head()
# Out:
#                                       COLLNAME     NACC  NUSERS RNACC RNUSERS  \
# 4         /SingleMu/Run2011A-PromptReco-v4/AOD  1537482    3571   1.4     1.3
# 7        /SingleMu/Run2011A-May10ReReco-v1/AOD  2851106    3082   2.6     1.1
# 3         /SingleMu/Run2011B-PromptReco-v1/AOD  1262370    2238   1.2     0.8
# 18        /DoubleMu/Run2011A-PromptReco-v4/AOD   502407    1959   0.5     0.7
# 11  /DoubleElectron/Run2011A-PromptReco-v4/AOD   657485    1942   0.6     0.7
#
#    RTOTCPU   TOTCPU         process             reprocessing datatype
# 4      2.8  1765946        SingleMu   Run2011A-PromptReco-v4      AOD
# 7      1.5   966514        SingleMu  Run2011A-May10ReReco-v1      AOD
# 3      3.0  1915483        SingleMu   Run2011B-PromptReco-v1      AOD
# 18     0.8   511015        DoubleMu   Run2011A-PromptReco-v4      AOD
# 11     1.2   746178  DoubleElectron   Run2011A-PromptReco-v4      AOD

# %% [markdown]
# Check which rows have the same process:

# %% [markdown]
# Build a new dataframe with sums by process, first take just the processes

# %%
df_byprocess = pd.DataFrame({'process': mc_df['process']})

# %%
df_byprocess.head(6)
# Out:
#                                         process
# 1   DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola
# 0        WJetsToLNu_TuneZ2_7TeV-madgraph-tauola
# 23           TTJets_TuneZ2_7TeV-madgraph-tauola
# 6   DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola
# 5        WJetsToLNu_TuneZ2_7TeV-madgraph-tauola
# 27       WJetsToLNu_TuneZ2_7TeV-madgraph-tauola

# %% [markdown]
# Remove multiple entries

# %%
df_byprocess = df_byprocess.drop_duplicates()

# %% [markdown]
# Add summed value for NUSERS and NACC to the new dataframe

# %% [markdown]
# Sum the values of NUSERS and NACC for each original entry. This is very slow, there must be a faster way of doing it.

# %%
nusers = []
nacc = []
for index, row in df_byprocess.iterrows():

# Sum only those positions (loc) where the process name in the full list is the same as the process name in the process list
    nusers.append(sum(mc_df['NUSERS'].loc[mc_df['process'] == df_byprocess['process'][index]]))
    nacc.append(sum(mc_df['NACC'].loc[mc_df['process'] == df_byprocess['process'][index]]))

# %% [markdown]
# Add the new summed values to the process dataframe

# %%
df_byprocess['nusers'] = nusers
df_byprocess['nacc'] = nacc

df_byprocess.head(6)
# Out:
#                                           process  nusers     nacc
# 1     DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola    7048  4020412
# 0          WJetsToLNu_TuneZ2_7TeV-madgraph-tauola    7496  6120395
# 23             TTJets_TuneZ2_7TeV-madgraph-tauola    6691  2643341
# 10    QCD_Pt-30to80_EMEnriched_TuneZ2_7TeV-pythia    1177  1274263
# 101         T_TuneZ2_t-channel_7TeV-powheg-tauola    1194   194141
# 46   DYToMuMu_M-20_CT10_TuneZ2_7TeV-powheg-pythia    2022  1244117

# %% [markdown]
# Order the new list by number of users

# %%
df_byprocess.sort_values('nusers',ascending=False)
# Out:
#                                                  process  nusers     nacc
# 0                 WJetsToLNu_TuneZ2_7TeV-madgraph-tauola    7496  6120395
# 1            DYJetsToLL_TuneZ2_M-50_7TeV-madgraph-tauola    7048  4020412
# 23                    TTJets_TuneZ2_7TeV-madgraph-tauola    6691  2643341
# 34         QCD_Pt-20_MuEnrichedPt-15_TuneZ2_7TeV-pythia6    2121  1128798
# 46          DYToMuMu_M-20_CT10_TuneZ2_7TeV-powheg-pythia    2022  1244117
# 468                          Hydjet_Bass_MinBias_2760GeV    1532   577072
# 349                    DYToMuMu_M-20_TuneZ2_7TeV-pythia6    1442   334359
# 21          QCD_Pt-20to30_EMEnriched_TuneZ2_7TeV-pythia6    1420  1093268
# 340                      DYToEE_M-20_TuneZ2_7TeV-pythia6    1244   364423
# 79     DYToTauTau_M-20_CT10_TuneZ2_7TeV-powheg-pythia...    1244   491433
# 124                        WZ_TuneZ2_7TeV_pythia6_tauola    1229   228784
# 135                        WW_TuneZ2_7TeV_pythia6_tauola    1224   210812
# 101                T_TuneZ2_t-channel_7TeV-powheg-tauola    1194   194141
# 10           QCD_Pt-30to80_EMEnriched_TuneZ2_7TeV-pythia    1177  1274263
# 181           DYToTauTau_M-20_TuneZ2_7TeV-pythia6-tauola    1157   362391
# 129                  QCD_Pt-170to300_TuneZ2_7TeV_pythia6    1146   268940
# 71         QCD_Pt-80to170_EMEnriched_TuneZ2_7TeV-pythia6    1134   330544
# 132                        ZZ_TuneZ2_7TeV_pythia6_tauola    1127   218518
# 144                  QCD_Pt-120to170_TuneZ2_7TeV_pythia6    1110   497676
# 302            T_TuneZ2_tW-channel-DR_7TeV-powheg-tauola    1110    56763
# 66            DYToEE_M-20_CT10_TuneZ2_7TeV-powheg-pythia    1107   637032
# 100                  QCD_Pt-300to470_TuneZ2_7TeV_pythia6    1041   257933
# 126                   QCD_Pt-80to120_TuneZ2_7TeV_pythia6    1025   407623
# 330         Tbar_TuneZ2_tW-channel-DR_7TeV-powheg-tauola    1013    52934
# 177                    QCD_Pt-50to80_TuneZ2_7TeV_pythia6     992   415370
# 314                        TT_TuneZ2_7TeV-pythia6-tauola     942   125822
# 168                  QCD_Pt-470to600_TuneZ2_7TeV_pythia6     912   179098
# 216             Tbar_TuneZ2_t-channel_7TeV-powheg-tauola     897    90461
# 176                  QCD_Pt-600to800_TuneZ2_7TeV_pythia6     856   181468
# 190                    QCD_Pt-30to50_TuneZ2_7TeV_pythia6     821   339655
# ...                                                  ...     ...      ...
# 11792  ZH_bbbarll_423p3_stdGeomTag003_PU25_NoDataLoss...       1       35
# 11752                 UNPART_Z_1_500_2000_MC_START311_V4       1      250
# 11833  LigtStop_mgluino475_mstop160_mneut80_7TeV_GEN_...       1       25
# 12239  LigtStop_mgluino335_mstop100_mneut60_7TeV_GEN_...       1       25
# 12243  LigtStop_mgluino335_mstop140_mneut120_7TeV_GEN...       1       25
# 12267  LigtStop_mgluino450_mstop175_mneut120_7TeV_GEN...       1       25
# 12387  LigtStop_mgluino335_mstop140_mneut135_7TeV_GEN...       1       25
# 12349  LigtStop_mgluino500_mstop160_mneut155_7TeV_GEN...       1       25
# 12340  LigtStop_mgluino375_mstop160_mneut140_7TeV_GEN...       1       25
# 12327  LigtStop_mgluino425_mstop175_mneut120_7TeV_GEN...       1       25
# 12314                             Wprime_1TeV_mu_oppsign       1       75
# 12309                  UNPART_Z_1_500_1000_MC_START42_v1       1       24
# 12299  LigtStop_mgluino350_mstop160_mneut60_7TeV_GEN_...       1       25
# 12352  LigtStop_mgluino350_mstop160_mneut120_7TeV_GEN...       1       25
# 12400  LigtStop_mgluino335_mstop120_mneut115_7TeV_GEN...       1       25
# 12396  LigtStop_mgluino275_mstop100_mneut60_7TeV_GEN_...       1       25
# 12393                 UNPART_Z_1_500_30000_MC_START42_v4       1       30
# 12379                           QQH200Inv_GEN-SIM_428_v1       1        4
# 12272  LigtStop_mgluino350_mstop140_mneut100_7TeV_GEN...       1       25
# 12198                                WZZNoGstar_Madgraph       1        1
# 12197  LigtStop_mgluino350_mstop100_mneut60_7TeV_GEN_...       1       25
# 12194  EXO_HSCP_Stoponlyneutral400_Summer11ReReproduc...       1       30
# 12183                                  DiJPsi_HLT11_SW42       1        4
# 12176  LigtStop_mgluino500_mstop140_mneut135_7TeV_GEN...       1       25
# 12168  LigtStop_mgluino400_mstop175_mneut80_7TeV_GEN_...       1       25
# 12161  LigtStop_mgluino400_mstop160_mneut155_7TeV_GEN...       1       25
# 12159  LigtStop_mgluino375_mstop160_mneut120_7TeV_GEN...       1       25
# 12150  LigtStop_mgluino500_mstop140_mneut120_7TeV_CMS...       1        7
# 12278         Hydjet17_MinBias_2760GeV_GEN-SIM-RAW_399p1       1       53
# 16026           GJet_PT_80toInf_TuneZ2_cJet_7TeV-pythia6       1        1
#
# [6528 rows x 3 columns]

# %%
np.savetxt(r'byprocess.txt', df_byprocess.sort_values('nusers',ascending=False), fmt='%s')
